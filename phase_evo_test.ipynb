# %%
import data
import phase_evolution as pe
import kicanalysis
# %matplotlib inline

# %%
allkics = data.select_kics()
ka = kicanalysis.kic_analyze(allkics[:])
ka.better_periods(files = ['periodogram_periods_all_interp_0.7','autocor_periods_all_interp_0.7'])
for kic in ka.better_periods.keys()[0:60]:
    time, flux, fluxerr, cadence, quarter, quality = data.loadlc_db(kic)
    pe.detrend(time,flux,quarter)
    pe.median_lc_corr(time,flux,ka.better_periods[kic][0],plot=True)
# Out:
# Found 2878 systems in catalog meeting criteria.
